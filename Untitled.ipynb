# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# **READING THE CSV FILE**

# %%
df=pd.read_csv('zomato.csv')
df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %% [markdown]
# **CHECK ROWS AND COLUMNS IN DATAFRAME**

# %%
df.shape
# Out:
# (9551, 21)

# %% [markdown]
# **CHECKING THE COLUMNS DATATYPE**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# **CHECK COLUMNS NAMES**

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# **DUPLICATES ROWS**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **FOR NUMERICAL COLUMNS WE MEAN ,MEDIAN ,STD,MIN,MAX**

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# **CHECK THE MISSING VALUES**

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# WE SEE THAT **CUISINES COLUMN** HAS NA VALUE

# %% [markdown]
# **WE ARE ONLY ANALYSING THE INDIAN RESURANT SO WE USE COUNTRY CODE 1**

# %%
Indian_res=df[df['Country Code']==1]

# %%
Indian_res.head()
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %%
city_votes=Indian_res.groupby(['City'])[['Votes']].sum()

# %%
city_votes.reset_index(inplace=True)

# %%
city_votes.sort_values(['Votes'],inplace=True)

# %%
city_votes.head()
# Out:
#           City  Votes
# 26      Mohali     99
# 33   Panchkula    843
# 4   Aurangabad   1296
# 2    Allahabad   1392
# 34       Patna   1520

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=city_votes,x='City',y='Votes',log=True,  edgecolor='Red')
plt.xticks(rotation=90)
plt.xlabel('CITY',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel('VOTES',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.title('TOTAL VOTES ACROSS EACH CITY',fontdict={'fontsize': 20, 'fontweight' : 10, 'color' : 'Green'})
plt.show()

# %% [markdown]
# **1)MOHALI HAS LEAST NUMBER OF VOTES**

# %% [markdown]
# **2)NEW DELHI HAS HIGHEST NUMBER OF VOTES**

# %%
Exce_rating=Indian_res[Indian_res['Rating text']=='Excellent']
Exce_rating
# Out:
#       Restaurant ID                    Restaurant Name  Country Code  \
# 637         3400346                    Sheroes Hangout             1
# 646        18396250                      Huber & Holly             1
# 653        18385201                           Cryo Lab             1
# 660          113325                     Nini's Kitchen             1
# 727           58268   The Fatty Bao - Asian Gastro Bar             1
# ...             ...                                ...           ...
# 9195          90499                         Coffee Cup             1
# 9216        3200090                      22nd Parallel             1
# 9228        3200311  La Quello - Mediterranean Kitchen             1
# 9256        2800013                          Pizza Hut             1
# 9262        2800856                    Barbeque Nation             1
#
#               City                                            Address  \
# ...

# %%
plt.figure(figsize=(16,8))
sns.countplot(data=Exce_rating,x='City',hue='Rating text',log=True,edgecolor='Red',saturation=2,color='Yellow')
plt.xticks(rotation=90)
plt.title('Number Of  Excellent Rating Resturant In Each City',fontdict={'fontsize': 20, 'fontweight' : 10, 'color' : 'Green'})
plt.xlabel('CITY',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel('COUNT',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.show()

# %% [markdown]
# **Top 5 City Which Has Excellent Rating**

# %% [markdown]
# 1)Delhi
# 2)Gurgaon
# 3)Chennai
# 4)Bangalore
# 5)Hyderabad

# %%
Resuratnat_high_no_votes=Indian_res.groupby(['Restaurant Name'])[['Votes']].sum().reset_index().sort_values(['Votes'],ascending=False)
Top_ten_resturant_according_to_votes=Resuratnat_high_no_votes.head(10)
Top_ten_resturant_according_to_votes
# Out:
#                 Restaurant Name  Votes
# 605             Barbeque Nation  27835
# 89    AB's - Absolute Barbecues  13400
# 6173                       Toit  10934
# 713                   Big Chill  10853
# 6204                   Truffles   9682
# 2047                 Farzi Cafe   9189
# 1355                    Chili's   8156
# 2550           Hauz Khas Social   7931
# 2876               Joey's Pizza   7807
# 4341                  Peter Cat   7574

# %%
plt.figure(figsize=(12,7))
sns.barplot(data=Top_ten_resturant_according_to_votes,x='Restaurant Name',y='Votes',saturation=7,edgecolor='Black')
plt.xticks(rotation=90)
plt.title("TOP 10 Restaurant According To Total Number of Votes",fontdict={'fontsize': 20, 'fontweight' : 10, 'color' : 'Green'})
plt.xlabel('Restaurant Name',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel('Votes',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.show()

# %% [markdown]
# **Barbeque Nation Has the highest number of votes in indian**

# %%
Resuratnat_high_no_votes=Indian_res.groupby(['Restaurant Name','City'])[['Votes']].sum().reset_index().sort_values(['Votes'],ascending=False)
Top_ten_resturant_according_to_votes_and_city=Resuratnat_high_no_votes.head(10).sort_values(['City'],ascending=False)
Top_ten_resturant_according_to_votes_and_city
# Out:
#                 Restaurant Name       City  Votes
# 773                   Big Chill  New Delhi  10853
# 2749           Hauz Khas Social  New Delhi   7931
# 782             Big Yellow Door  New Delhi   7511
# 5325            Saravana Bhavan  New Delhi   7238
# 3091               Joey's Pizza     Mumbai   7807
# 637             Barbeque Nation    Kolkata   7719
# 4670                  Peter Cat    Kolkata   7574
# 6629                       Toit  Bangalore  10934
# 6663                   Truffles  Bangalore   9667
# 91    AB's - Absolute Barbecues  Bangalore   6907

# %%
plt.figure(figsize=(12,7))
sns.barplot(data=Top_ten_resturant_according_to_votes_and_city,hue='Restaurant Name',x='City',y='Votes',saturation=7,edgecolor='Black')
plt.xticks(rotation=90)
plt.title("TOP 10 Restaurant According To Total Number of Votes and city",fontdict={'fontsize': 20, 'fontweight' : 10, 'color' : 'Green'})
plt.xlabel('Restaurant Name',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel('Votes',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.show()

# %% [markdown]
# **IN Delhi 'Big chill' highest number of votes**

# %%
Indian_res['Rating text'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
Indian_res['Rating color'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
Indian_res['Aggregate rating'].value_counts()
# Out:
# 0.0    2139
# 3.1     511
# 3.2     510
# 3.4     477
# 3.3     472
# 3.0     465
# 3.5     454
# 3.6     411
# 2.9     380
# 3.7     363
# 3.8     336
# 2.8     314
# 3.9     283
# 2.7     250
# 4.0     193
# 2.6     190
# 4.1     185
# 4.2     140
# 2.5     109
# 4.3     100
# 2.4      83
# 4.4      74
# 2.3      46
# 4.5      37
# 4.6      35
# 2.2      26
# 4.9      19
# 4.7      16
# 2.1      15
# 4.8       9
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
Indian_res['Price range'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
Indian_res['Average Cost for two'].value_counts().plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.set_style('white')
re=Indian_res.corr()

re=re.drop(['Country Code','Restaurant ID','Longitude','Latitude'],axis=1)
re=re.drop(['Country Code','Restaurant ID','Longitude','Latitude'],axis=0)

# %%
plt.figure(figsize=(12,7))
sns.heatmap(re,annot=True)
plt.show()

# %%
def pairplot(s):
    sns.pairplot(s)

# %%
s=Indian_res.loc[:,['Votes','Aggregate rating','Average Cost for two','Price range']]
pairplot(s)

# %%
Expensive_resturant=Indian_res[(Indian_res['Price range']==4) & (Indian_res['Rating text'].isin(['Very Good','Excellent']))]

# %%
Expensive_resturant.describe()
# Out:
#        Restaurant ID  Country Code   Longitude    Latitude  \
# count   1.170000e+02         117.0  117.000000  117.000000
# mean    5.840376e+06           1.0   73.200662   24.827344
# std     7.945476e+06           0.0   17.210102    7.550657
# min     9.100000e+02           1.0    0.000000    0.000000
# 25%     1.022150e+05           1.0   77.041790   26.172119
# 50%     3.132070e+05           1.0   77.196928   28.526783
# 75%     1.802221e+07           1.0   77.232208   28.599732
# max     1.846200e+07           1.0   91.759857   30.885814
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count            117.000000        117.0        117.000000    117.000000
# mean            2492.735043          4.0          4.268376    772.709402
# std             1223.975028          0.0          0.254832   1254.801297
# min             1000.000000          4.0          4.000000     37.000000
# ...

# %%
Expensive_resturant.sort_values(['Votes','Aggregate rating'],ascending=False,inplace=True)
# Out:
# <ipython-input-42-00f16621fd53>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Expensive_resturant.sort_values(['Votes','Aggregate rating'],ascending=False,inplace=True)

# %%
Expensive_resturant.head(5)
# Out:
#       Restaurant ID       Restaurant Name  Country Code       City  \
# 728           51705                  Toit             1  Bangalore
# 1252         308022            Farzi Cafe             1    Gurgaon
# 821           65055       Barbeque Nation             1    Chennai
# 4087           2742  Bukhara - ITC Maurya             1  New Delhi
# 1555           8913      Pirates of Grill             1    Gurgaon
#
#                                                 Address  \
# 728   298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# 1252  7-8, Ground Floor, Cyber Hub, DLF Cyber City, ...
# 821   Shri Devi Park Hotel, 1, Hanumantha Road, Nort...
# 4087                ITC Maurya, Chanakyapuri, New Delhi
# 1555  Ground Floor, MGF Mega City Mall, MG Road, Gur...
#
#                          Locality                      Locality Verbose  \
# 728                   Indiranagar                Indiranagar, Bangalore
# 1252    Cyber Hub, DLF Cyber City    Cyber Hub, DLF Cyber City, Gurgaon
# ...

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=Expensive_resturant.head(5),x='Restaurant Name',y='Votes',saturation=7,edgecolor='black')
plt.xticks(rotation=90)
plt.title('Top 5 Expensive Restaurant',fontdict={'fontsize': 20, 'fontweight' : 10, 'color' : 'Green'})
plt.xlabel('Restaurant',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel('Votes',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.show()

# %%
Cheap_restaurant=Indian_res[(Indian_res['Price range'].isin([1]))& (Indian_res['Rating text'].isin(['Very Good','Excellent']))]

# %%
Cheap_restaurant=Cheap_restaurant.sort_values(['Votes','Aggregate rating'],ascending=False)
Cheap_restaurant.head(5)
# Out:
#       Restaurant ID     Restaurant Name  Country Code       City  \
# 3119           4249            Wenger's             1  New Delhi
# 3599           4631       Andhra Bhavan             1  New Delhi
# 3013         310143  Naturals Ice Cream             1  New Delhi
# 811           70890     Fusilli Reasons             1    Chennai
# 3118         301114       Wenger's Deli             1  New Delhi
#
#                                                 Address          Locality  \
# 3119                   A-16, Connaught Place, New Delhi   Connaught Place
# 3599        1, Ashoka Road, Feroze Shah Road, New Delhi  Feroze Shah Road
# 3013      L-8, Outer Circle, Connaught Place, New Delhi   Connaught Place
# 811   1/9, Dr. Vasudevan Street, Ormes Road, Kilpauk...           Kilpauk
# 3118      A-18, Radial Road, Connaught Place, New Delhi   Connaught Place
#
#                  Locality Verbose  Longitude   Latitude  \
# 3119   Connaught Place, New Delhi  77.218333  28.633368
# ...

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=Cheap_restaurant.head(5),x='Restaurant Name',y='Votes',saturation=7,edgecolor='black')
plt.xticks(rotation=90)
plt.title('Top 5 Cheap Restaurant',fontdict={'fontsize': 20, 'fontweight' : 10, 'color' : 'Green'})
plt.xlabel('Restaurant',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel('Votes',fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Brown'})
plt.show()

# %%
Indian_res
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 624         3400025                             Jahanpanah             1
# 625         3400341                    Rangrezz Restaurant             1
# 626         3400005                Time2Eat - Mama Chicken             1
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                         Pinch Of Spice             1
# ...             ...                                    ...           ...
# 9271        2800100                               D Cabana             1
# 9272        2800418                               Kaloreez             1
# 9273        2800881                                Plot 17             1
# 9274        2800042                       Vista - The Park             1
# 9275        2800019               Flying Spaghetti Monster             1
#
#        City                                            Address  \
# ...

# %%
Indian_res['Cuisines'].value_counts().head(20)
# Out:
# North Indian                      936
# North Indian, Chinese             511
# Fast Food                         348
# Chinese                           340
# North Indian, Mughlai             334
# Cafe                              279
# Bakery                            216
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Pizza, Fast Food                  130
# Chinese, Fast Food                118
# Mithai, Street Food               116
# South Indian                      111
# Bakery, Fast Food                 108
# Chinese, North Indian             105
# Mughlai                           103
# Ice Cream, Desserts                82
# North Indian, Fast Food            74
# Ice Cream                          74
# Name: Cuisines, dtype: int64

# %%
Indian_res.groupby(['City'])['Cuisines'].value_counts()
# Out:
# City   Cuisines
# Agra   North Indian, Mughlai                                        5
#        North Indian, Chinese, Continental                           2
#        Cafe, Italian, Mexican, North Indian, Continental            1
#        Cafe, North Indian, Chinese                                  1
#        Chinese, Italian, Continental, North Indian                  1
#                                                                    ..
# Vizag  Mughlai, Chinese, Cafe, BBQ, Cajun                           1
#        North Indian, Biryani                                        1
#        North Indian, Chinese, Mediterranean                         1
#        South Indian, Chinese, Continental, Italian, North Indian    1
#        South Indian, North Indian                                   1
# Name: Cuisines, Length: 2220, dtype: int64

# %%
from collections import Counter
sd=Indian_res['Cuisines']
language_counter=Counter()
for i in sd:
    language_counter.update(i.split(','))
language=[]
popularity=[]
for item in language_counter.most_common(15):
    language.append(item[0])
    popularity.append(item[1])

# %%
print(language)
print(popularity)
# Out:
# ['North Indian', ' Chinese', ' Fast Food', ' North Indian', 'Chinese', ' Mughlai', 'Fast Food', 'Bakery', 'Cafe', ' Italian', ' Continental', ' Desserts', ' South Indian', ' Street Food', 'South Indian']
# [2990, 1861, 1305, 956, 829, 777, 658, 616, 561, 505, 495, 467, 370, 320, 261]
